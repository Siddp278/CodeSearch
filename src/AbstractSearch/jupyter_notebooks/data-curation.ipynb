# %%
from google.colab import drive
drive.mount('/content/drive')

import os

os.chdir("/content/drive/MyDrive/Colab Notebooks/Searched Ranking/")
os.getcwd()
# Out:
# Mounted at /content/drive
# '/content/drive/MyDrive/Colab Notebooks/Searched Ranking'

# %%
import pandas as pd
import numpy as np

# %%
print(pd.__version__)
print(np.__version__)
# Out:
# 2.0.1+cu118
# 1.5.3
# 2.2.2
# 1.7.2
# 1.23.5

# %%
# Read a CSV in a table
df = pd.read_csv('data/data.csv')
# df = df.assign(IndexColumn=df.index)

df.head()
# Out:
# <ipython-input-6-d386047f2965>:2: DtypeWarning: Columns (1,4,5,6,13,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/data.csv')
#    cord_uid                                       sha source_x  \
# 0  ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1  02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
# 2  ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927      PMC
# 3  2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605      PMC
# 4  9785vg6d  5f48792a5fa08bed9f56016f4981ae2ca6031b32      PMC
#
#                                                title                    doi  \
# 0  Clinical features of culture-proven Mycoplasma...  10.1186/1471-2334-1-6
# 1  Nitric oxide: a pro-inflammatory mediator in l...           10.1186/rr14
# 2    Surfactant protein-D and pulmonary host defense           10.1186/rr19
# 3               Role of endothelin-1 in lung disease           10.1186/rr44
# ...

# %%
df.shape
# Out:
# (1056660, 20)

# %%
df.abstract.isnull().sum()
# Out:
# 235542

# %%
# Removing all the null values

df_ = df[["title", "abstract"]].dropna(how="any")

df_.shape
# Out:
# (821007, 2)

# %%
import gc  # Import the garbage collection module

# Assuming you have a DataFrame named 'df'
del df  # Delete the DataFrame

# Run the garbage collector to release memory
gc.collect()
# Out:
# 0

# %%
print(df_.isnull().sum())
df_.head()
# Out:
# title       0
# abstract    0
# dtype: int64
#                                                title  \
# 0  Clinical features of culture-proven Mycoplasma...
# 1  Nitric oxide: a pro-inflammatory mediator in l...
# 2    Surfactant protein-D and pulmonary host defense
# 3               Role of endothelin-1 in lung disease
# 4  Gene expression in epithelial cells in respons...
#
#                                             abstract
# 0  OBJECTIVE: This retrospective chart review des...
# 1  Inflammatory diseases of the respiratory tract...
# 2  Surfactant protein-D (SP-D) participates in th...
# 3  Endothelin-1 (ET-1) is a 21 amino acid peptide...
# 4  Respiratory syncytial virus (RSV) and pneumoni...

# %%
df_.shape
# Out:
# (821007, 2)

# %%
arr = np.arange(stop=821007, dtype=int)

df_["index"] = arr

df_.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-1959faa6f425> in <cell line: 3>()
#       1 arr = np.arange(start=1, stop=821007, step=22, dtype=int)
#       2
# ----> 3 df_["index"] = arr
#       4
#       5 df_.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3978         else:
#    3979             # set column
# -> 3980             self._set_item(key, value)
#    3981
#    3982     def _setitem_slice(self, key: slice, value):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4172         ensure homogeneity.
#    4173         """
# -> 4174         value = self._sanitize_column(value)
#    4175
#    4176         if (
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4913
# ...

# %%
df_.to_csv("data/data_curated.csv")
